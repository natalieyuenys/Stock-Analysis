# %%
import requests
import pandas as pd
import json
from datetime import datetime
import time
import os
from dotenv import load_dotenv
from alpha_vantage.fundamentaldata import FundamentalData

# %%
class FundamentalDataExtractor:
    def __init__(self, api_key=None):
        self.api_key = api_key
        self.base_url = "https://www.alphavantage.co/query"

        # Top tech company tickers for 2025
        self.tech_tickers = {
            'AAPL': 'Apple Inc.',
            # 'MSFT': 'Microsoft Corporation', 
            # 'GOOGL': 'Alphabet Inc.',
            # 'AMZN': 'Amazon.com Inc.',
            # 'META': 'Meta Platforms Inc.',
            # 'TSLA': 'Tesla Inc.',
            # 'NVDA': 'NVIDIA Corporation',
            # 'NFLX': 'Netflix Inc.',
            # 'CRM': 'Salesforce Inc.',
            # 'AMD': 'Advanced Micro Devices'
        }
    def get_fundamentals(self,ticker):
        fd = FundamentalData(key=self.api_key, output_format='pandas')
        overview, _ = fd.get_company_overview(symbol=ticker)
        income, _ = fd.get_income_statement_annual(symbol=ticker)
        balance, _ = fd.get_balance_sheet_annual(symbol=ticker)
        cashflow, _ = fd.get_cash_flow_annual(symbol=ticker)
        return overview, income, balance, cashflow

# %%
load_dotenv()
api_key = os.getenv('ALPHA_VANTAGE_API_KEY')

# %%
results = pd.DataFrame()
Extractor = FundamentalDataExtractor(api_key)
for i, (ticker, company_name) in enumerate(Extractor.tech_tickers.items(), 1):
    print(f"Processing {i}/{len(Extractor.tech_tickers)}: {ticker} ({company_name})")
    overview, income, balance, cashflow = Extractor.get_fundamentals(ticker)
    df = pd.concat([overview, income, balance, cashflow], axis=1)
    df['ticker'] = ticker
    df['company_name'] = company_name   
    results = pd.concat([results, df], axis=0)
# Out:
# Processing 1/10: AAPL (Apple Inc.)
# Processing 2/10: MSFT (Microsoft Corporation)
# Processing 3/10: GOOGL (Alphabet Inc.)
# Processing 4/10: AMZN (Amazon.com Inc.)
# Processing 5/10: META (Meta Platforms Inc.)
# Processing 6/10: TSLA (Tesla Inc.)
# Processing 7/10: NVDA (NVIDIA Corporation)
# Processing 8/10: NFLX (Netflix Inc.)
# Processing 9/10: CRM (Salesforce Inc.)
# Processing 10/10: AMD (Advanced Micro Devices)

# %%
results
# Out:
#                               Symbol     AssetType       Name  \
# NaT                             AAPL  Common Stock  Apple Inc
# 1970-01-01 00:00:00.000000000    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000001    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000002    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000003    NaN           NaN        NaN
# ...                              ...           ...        ...
# 1970-01-01 00:00:00.000000015    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000016    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000017    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000018    NaN           NaN        NaN
# 1970-01-01 00:00:00.000000019    NaN           NaN        NaN
#
#                                                                      Description  \
# NaT                            Apple Inc. is an American multinational techno...
# 1970-01-01 00:00:00.000000000                                                NaN
# 1970-01-01 00:00:00.000000001                                                NaN
# 1970-01-01 00:00:00.000000002                                                NaN
# 1970-01-01 00:00:00.000000003                                                NaN
# ...                                                                          ...
# 1970-01-01 00:00:00.000000015                                                NaN
# 1970-01-01 00:00:00.000000016                                                NaN
# 1970-01-01 00:00:00.000000017                                                NaN
# 1970-01-01 00:00:00.000000018                                                NaN
# 1970-01-01 00:00:00.000000019                                                NaN
#
#                                   CIK Exchange Currency Country      Sector  \
# NaT                            320193   NASDAQ      USD     USA  TECHNOLOGY
# 1970-01-01 00:00:00.000000000     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000001     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000002     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000003     NaN      NaN      NaN     NaN         NaN
# ...                               ...      ...      ...     ...         ...
# 1970-01-01 00:00:00.000000015     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000016     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000017     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000018     NaN      NaN      NaN     NaN         NaN
# 1970-01-01 00:00:00.000000019     NaN      NaN      NaN     NaN         NaN
#
#                                            Industry  ...  \
# NaT                            ELECTRONIC COMPUTERS  ...
# 1970-01-01 00:00:00.000000000                   NaN  ...
# 1970-01-01 00:00:00.000000001                   NaN  ...
# 1970-01-01 00:00:00.000000002                   NaN  ...
# 1970-01-01 00:00:00.000000003                   NaN  ...
# ...                                             ...  ...
# 1970-01-01 00:00:00.000000015                   NaN  ...
# 1970-01-01 00:00:00.000000016                   NaN  ...
# 1970-01-01 00:00:00.000000017                   NaN  ...
# 1970-01-01 00:00:00.000000018                   NaN  ...
# 1970-01-01 00:00:00.000000019                   NaN  ...
#
#                               proceedsFromIssuanceOfCommonStock  \
# NaT                                                         NaN
# 1970-01-01 00:00:00.000000000                              None
# 1970-01-01 00:00:00.000000001                              None
# 1970-01-01 00:00:00.000000002                              None
# 1970-01-01 00:00:00.000000003                              None
# ...                                                         ...
# 1970-01-01 00:00:00.000000015                              None
# 1970-01-01 00:00:00.000000016                              None
# 1970-01-01 00:00:00.000000017                              None
# 1970-01-01 00:00:00.000000018                              None
# 1970-01-01 00:00:00.000000019                              None
#
#                               proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet  \
# NaT                                                                          NaN
# 1970-01-01 00:00:00.000000000                                               None
# 1970-01-01 00:00:00.000000001                                               None
# 1970-01-01 00:00:00.000000002                                               None
# 1970-01-01 00:00:00.000000003                                               None
# ...                                                                          ...
# 1970-01-01 00:00:00.000000015                                               None
# 1970-01-01 00:00:00.000000016                                               None
# 1970-01-01 00:00:00.000000017                                               None
# 1970-01-01 00:00:00.000000018                                               None
# 1970-01-01 00:00:00.000000019                                               None
#
#                               proceedsFromIssuanceOfPreferredStock  \
# NaT                                                            NaN
# 1970-01-01 00:00:00.000000000                                 None
# 1970-01-01 00:00:00.000000001                                 None
# 1970-01-01 00:00:00.000000002                                 None
# 1970-01-01 00:00:00.000000003                                 None
# ...                                                            ...
# 1970-01-01 00:00:00.000000015                                 None
# 1970-01-01 00:00:00.000000016                                 None
# 1970-01-01 00:00:00.000000017                                 None
# 1970-01-01 00:00:00.000000018                                 None
# 1970-01-01 00:00:00.000000019                                 None
#
#                               proceedsFromRepurchaseOfEquity  \
# NaT                                                      NaN
# 1970-01-01 00:00:00.000000000                   -94949000000
# 1970-01-01 00:00:00.000000001                   -77550000000
# 1970-01-01 00:00:00.000000002                   -89402000000
# 1970-01-01 00:00:00.000000003                   -85971000000
# ...                                                      ...
# 1970-01-01 00:00:00.000000015                     1273000000
# 1970-01-01 00:00:00.000000016                      161000000
# 1970-01-01 00:00:00.000000017                      909000000
# 1970-01-01 00:00:00.000000018                           None
# 1970-01-01 00:00:00.000000019                      352800000
#
#                               proceedsFromSaleOfTreasuryStock  \
# NaT                                                       NaN
# 1970-01-01 00:00:00.000000000                            None
# 1970-01-01 00:00:00.000000001                            None
# 1970-01-01 00:00:00.000000002                            None
# 1970-01-01 00:00:00.000000003                            None
# ...                                                       ...
# 1970-01-01 00:00:00.000000015                            None
# 1970-01-01 00:00:00.000000016                            None
# 1970-01-01 00:00:00.000000017                            None
# 1970-01-01 00:00:00.000000018                            None
# 1970-01-01 00:00:00.000000019                            None
#
#                               changeInCashAndCashEquivalents  \
# NaT                                                      NaN
# 1970-01-01 00:00:00.000000000                           None
# 1970-01-01 00:00:00.000000001                     5760000000
# 1970-01-01 00:00:00.000000002                   -10952000000
# 1970-01-01 00:00:00.000000003                    -3860000000
# ...                                                      ...
# 1970-01-01 00:00:00.000000015                           None
# 1970-01-01 00:00:00.000000016                           None
# 1970-01-01 00:00:00.000000017                           None
# 1970-01-01 00:00:00.000000018                           None
# 1970-01-01 00:00:00.000000019                           None
#
#                               changeInExchangeRate    netIncome ticker  \
# NaT                                            NaN          NaN   AAPL
# 1970-01-01 00:00:00.000000000                 None  93736000000   AAPL
# 1970-01-01 00:00:00.000000001                 None  96995000000   AAPL
# 1970-01-01 00:00:00.000000002                 None  99803000000   AAPL
# 1970-01-01 00:00:00.000000003                 None  94680000000   AAPL
# ...                                            ...          ...    ...
# 1970-01-01 00:00:00.000000015                 None    293000000    AMD
# 1970-01-01 00:00:00.000000016                 None  -3098000000    AMD
# 1970-01-01 00:00:00.000000017                 None  -3379000000    AMD
# 1970-01-01 00:00:00.000000018                 None   -166000000    AMD
# 1970-01-01 00:00:00.000000019                 None    165483000    AMD
#
#                                          company_name
# NaT                                        Apple Inc.
# 1970-01-01 00:00:00.000000000              Apple Inc.
# 1970-01-01 00:00:00.000000001              Apple Inc.
# 1970-01-01 00:00:00.000000002              Apple Inc.
# 1970-01-01 00:00:00.000000003              Apple Inc.
# ...                                               ...
# 1970-01-01 00:00:00.000000015  Advanced Micro Devices
# 1970-01-01 00:00:00.000000016  Advanced Micro Devices
# 1970-01-01 00:00:00.000000017  Advanced Micro Devices
# 1970-01-01 00:00:00.000000018  Advanced Micro Devices
# 1970-01-01 00:00:00.000000019  Advanced Micro Devices
#
# [207 rows x 150 columns]
